# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import sys

# %%
#Only in Drive, stay in commend in VSCode
#from google.colab import drive 
#drive.mount('/content/gdrive')

# %%
#Read the file data and see the table 
df = pd.read_csv('Data/iris.data', header= None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
#Rename the table 
col_name = ['speal lenght', 'sepal width', 'petal lenght', 'petal width', 'class']
df.columns = col_name
#df.head()

# %%
#df.describe()
#print(iris.info())
#iris.head()
#Uploaded data set from seaborn
iris = sns.load_dataset('iris')
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
sns.pairplot(iris, hue= 'species', height= 3, aspect=1)

# %%
iris.hist(edgecolor='black', linewidth=0.5, figsize=(6,8))
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(x='species', y= 'sepal_length', data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species', y= 'sepal_width', data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species', y= 'petal_length', data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species', y= 'petal_width', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
iris.boxplot(by='species', figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)
